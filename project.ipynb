# %% [raw]
# **Libraries**

# %%
hospital  = pd.read_csv("../input/hospitalbedloc/HospitalBedsIndiaLocations.csv")

# %% [markdown]
#  **Hospitals in India**

# %%
hospital.head()
# Out:
#    Sno                   State/UT  NumPrimaryHealthCenters_HMIS  \
# 0    1  Andaman & Nicobar Islands                            27
# 1    2             Andhra Pradesh                          1417
# 2    3          Arunachal Pradesh                           122
# 3    4                      Assam                          1007
# 4    5                      Bihar                          2007
#
#    NumCommunityHealthCenters_HMIS  NumSubDistrictHospitals_HMIS  \
# 0                               4                           NaN
# 1                             198                          31.0
# 2                              62                           NaN
# 3                             166                          14.0
# 4                              63                          33.0
#
#    NumDistrictHospitals_HMIS  TotalPublicHealthFacilities_HMIS  \
# 0                          3                                34
# 1                         20                              1666
# 2                         15                               199
# 3                         33                              1220
# 4                         43                              2146
#
#    NumPublicBeds_HMIS  NumRuralHospitals_NHP18  NumRuralBeds_NHP18  \
# 0                1246                       27                 575
# 1               60799                      193                6480
# 2                2320                      208                2136
# 3               19115                     1176               10944
# 4               17796                      930                6083
#
#    NumUrbanHospitals_NHP18  NumUrbanBeds_NHP18  Latitude  Longitude
# 0                        3                 500   11.6234    92.7265
# 1                       65               16658   15.9129    79.7400
# 2                       10                 268   27.0844    93.6053
# 3                       50                6198   26.1433    91.7898
# 4                      103                5936   25.5941    85.1376

# %% [markdown]
# **This file contain Health Management Information System data and National Health Profile Data and we deal diffrently with them**

# %%
hmis = hospital.loc[:,['Sno','State/UT','Latitude','Longitude','NumPrimaryHealthCenters_HMIS','NumCommunityHealthCenters_HMIS','NumSubDistrictHospitals_HMIS','NumDistrictHospitals_HMIS','TotalPublicHealthFacilities_HMIS','NumPublicBeds_HMIS']]

# %%
nhp = hospital.loc[:,['Sno','State/UT','Latitude','Longitude','NumRuralHospitals_NHP18','NumRuralBeds_NHP18','NumUrbanHospitals_NHP18','NumUrbanBeds_NHP18']]

# %%
hmis = hmis.rename(columns={"State/UT":"State","NumPrimaryHealthCenters_HMIS":"Primary","NumCommunityHealthCenters_HMIS":"Community","NumSubDistrictHospitals_HMIS":"SubDistrict","NumDistrictHospitals_HMIS":"District","TotalPublicHealthFacilities_HMIS":"Total","NumPublicBeds_HMIS":"Public beds"})

# %%
nhp = nhp.rename(columns={'State/UT':"State",'NumRuralHospitals_NHP18':"Rural_hospitals",'NumRuralBeds_NHP18':"Rural_beds",'NumUrbanHospitals_NHP18':"Urban_hospitals",'NumUrbanBeds_NHP18':"Urban_beds"})

# %%
hmis = hmis.fillna(0)

# %%
hmis.head()
# Out:
#    Sno                      State  Latitude  Longitude  Primary  Community  \
# 0    1  Andaman & Nicobar Islands   11.6234    92.7265       27          4
# 1    2             Andhra Pradesh   15.9129    79.7400     1417        198
# 2    3          Arunachal Pradesh   27.0844    93.6053      122         62
# 3    4                      Assam   26.1433    91.7898     1007        166
# 4    5                      Bihar   25.5941    85.1376     2007         63
#
#    SubDistrict  District  Total  Public beds
# 0          0.0         3     34         1246
# 1         31.0        20   1666        60799
# 2          0.0        15    199         2320
# 3         14.0        33   1220        19115
# 4         33.0        43   2146        17796

# %% [markdown]
# **HMIS Hospitals in World Map**

# %%
import folium
india = folium.Map(location=[20.5937,78.9629 ], zoom_start=5,tiles='cartodbpositron')

for lat, lon,State,Primary ,Community, SubDistrict, District, Total in zip(hmis['Latitude'], hmis['Longitude'],hmis['State'],hmis['Total'],hmis['Primary'],hmis['Community'],hmis['SubDistrict'],hmis['District']):
    folium.CircleMarker([lat, lon],
                        radius=5,
                        color='red',
                      popup =('State:' + str(State) + '<br>'
                             'Total Hospitals:' + str(Total) + '<br>'
                              'Primary :' + str(Primary) + '<br>'
                             'Community:' + str(Community) + '<br>'
                             'Sub District:'+ str(SubDistrict) + '<br>'
                             'District:'+ str(District) + '<br>'

                             ),
                        
                        fill_color='red',
                        fill_opacity=0.7 ).add_to(india)
india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
hmis = hmis.sort_values(by='Total', ascending=False)

# %%
fig = px.bar(hmis[['State', 'Total']].sort_values('Total', ascending=False), 
             y="Total", x="State", color='State', 
             log_y=True, template='ggplot2', title='Total Hospitals')
fig.show()
# Out:
# <div>
#
#
#             <div id="dd02fed7-8931-4b1e-a923-b7dbe940f885" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd02fed7-8931-4b1e-a923-b7dbe940f885")) {
#                     Plotly.newPlot(
#                         'dd02fed7-8931-4b1e-a923-b7dbe940f885',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Uttar Pradesh", "marker": {"color": "#F8766D"}, "name": "Uttar Pradesh", "offsetgroup": "Uttar Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Uttar Pradesh"], "xaxis": "x", "y": [4122], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Maharashtra", "marker": {"color": "#A3A500"}, "name": "Maharashtra", "offsetgroup": "Maharashtra", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Maharashtra"], "xaxis": "x", "y": [3239], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Rajasthan", "marker": {"color": "#00BF7D"}, "name": "Rajasthan", "offsetgroup": "Rajasthan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Rajasthan"], "xaxis": "x", "y": [3139], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#00B0F6"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [2943], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Tamil Nadu", "marker": {"color": "#E76BF3"}, "name": "Tamil Nadu", "offsetgroup": "Tamil Nadu", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tamil Nadu"], "xaxis": "x", "y": [2581], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Gujarat", "marker": {"color": "#F8766D"}, "name": "Gujarat", "offsetgroup": "Gujarat", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Gujarat"], "xaxis": "x", "y": [2236], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Bihar", "marker": {"color": "#A3A500"}, "name": "Bihar", "offsetgroup": "Bihar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bihar"], "xaxis": "x", "y": [2146], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#00BF7D"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [1905], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Madhya Pradesh", "marker": {"color": "#00B0F6"}, "name": "Madhya Pradesh", "offsetgroup": "Madhya Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh"], "xaxis": "x", "y": [1867], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Odisha", "marker": {"color": "#E76BF3"}, "name": "Odisha", "offsetgroup": "Odisha", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Odisha"], "xaxis": "x", "y": [1799], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total=%{y}", "legendgroup": "Andhra Pradesh", "marker": {"color": "#F8766D"}, "name": "Andhra Pradesh", "offsetgroup": "Andhra Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Andhra Pradesh"], "xaxis": "x", "y": [1666], "yaxis": "y"}, {"alignmentgroup": "True", "ho ...

# %%
fig = px.bar(hmis[['State', 'Primary']].sort_values('Primary', ascending=False), 
             y="Primary", x="State", color='State', 
             log_y=True, template='ggplot2', title='Primary Hospitals')
fig.show()
# Out:
# <div>
#
#
#             <div id="fea98fc4-fcbd-4571-9faf-f775d1cd9ef2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fea98fc4-fcbd-4571-9faf-f775d1cd9ef2")) {
#                     Plotly.newPlot(
#                         'fea98fc4-fcbd-4571-9faf-f775d1cd9ef2',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Uttar Pradesh", "marker": {"color": "#F8766D"}, "name": "Uttar Pradesh", "offsetgroup": "Uttar Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Uttar Pradesh"], "xaxis": "x", "y": [3277], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Maharashtra", "marker": {"color": "#A3A500"}, "name": "Maharashtra", "offsetgroup": "Maharashtra", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Maharashtra"], "xaxis": "x", "y": [2638], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#00BF7D"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [2547], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Rajasthan", "marker": {"color": "#00B0F6"}, "name": "Rajasthan", "offsetgroup": "Rajasthan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Rajasthan"], "xaxis": "x", "y": [2463], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Bihar", "marker": {"color": "#E76BF3"}, "name": "Bihar", "offsetgroup": "Bihar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bihar"], "xaxis": "x", "y": [2007], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Tamil Nadu", "marker": {"color": "#F8766D"}, "name": "Tamil Nadu", "offsetgroup": "Tamil Nadu", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tamil Nadu"], "xaxis": "x", "y": [1854], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Gujarat", "marker": {"color": "#A3A500"}, "name": "Gujarat", "offsetgroup": "Gujarat", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Gujarat"], "xaxis": "x", "y": [1770], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Madhya Pradesh", "marker": {"color": "#00BF7D"}, "name": "Madhya Pradesh", "offsetgroup": "Madhya Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh"], "xaxis": "x", "y": [1420], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Andhra Pradesh", "marker": {"color": "#00B0F6"}, "name": "Andhra Pradesh", "offsetgroup": "Andhra Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Andhra Pradesh"], "xaxis": "x", "y": [1417], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#E76BF3"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [1374], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Primary=%{y}", "legendgroup": "Odisha", "marker": {"color": "#F8766D"}, "name": "Odisha", "offsetgroup": "Odisha", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Odisha"], "xaxis": "x", "y": [1360], "yaxis": "y"}, {"alignm ...

# %%
fig = px.bar(hmis[['State', 'Community']].sort_values('Community', ascending=False), 
             y="Community", x="State", color='State', 
             log_y=True, template='ggplot2', title='Community Hospitals')
fig.show()
# Out:
# <div>
#
#
#             <div id="21189467-3d7b-469d-8f35-9ed64b35e4e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("21189467-3d7b-469d-8f35-9ed64b35e4e1")) {
#                     Plotly.newPlot(
#                         '21189467-3d7b-469d-8f35-9ed64b35e4e1',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Uttar Pradesh", "marker": {"color": "#F8766D"}, "name": "Uttar Pradesh", "offsetgroup": "Uttar Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Uttar Pradesh"], "xaxis": "x", "y": [671], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Rajasthan", "marker": {"color": "#A3A500"}, "name": "Rajasthan", "offsetgroup": "Rajasthan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Rajasthan"], "xaxis": "x", "y": [579], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Maharashtra", "marker": {"color": "#00BF7D"}, "name": "Maharashtra", "offsetgroup": "Maharashtra", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Maharashtra"], "xaxis": "x", "y": [430], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#00B0F6"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [406], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Tamil Nadu", "marker": {"color": "#E76BF3"}, "name": "Tamil Nadu", "offsetgroup": "Tamil Nadu", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tamil Nadu"], "xaxis": "x", "y": [385], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Gujarat", "marker": {"color": "#F8766D"}, "name": "Gujarat", "offsetgroup": "Gujarat", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Gujarat"], "xaxis": "x", "y": [385], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Odisha", "marker": {"color": "#A3A500"}, "name": "Odisha", "offsetgroup": "Odisha", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Odisha"], "xaxis": "x", "y": [377], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Madhya Pradesh", "marker": {"color": "#00BF7D"}, "name": "Madhya Pradesh", "offsetgroup": "Madhya Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh"], "xaxis": "x", "y": [324], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Kerala", "marker": {"color": "#00B0F6"}, "name": "Kerala", "offsetgroup": "Kerala", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Kerala"], "xaxis": "x", "y": [229], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#E76BF3"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [207], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Community=%{y}", "legendgroup": "Andhra Pradesh", "marker": {"color": "#F8766D"}, "name": "Andhra Pradesh", "offsetgroup": "Andhra Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Andhra Pradesh"], "xaxis": "x", "y": [198], "yaxis": ...

# %%
fig = px.bar(hmis[['State', 'District']].sort_values('District', ascending=False), 
             y="District", x="State", color='State', 
             log_y=True, template='ggplot2', title='District Hospitals')
fig.show()
# Out:
# <div>
#
#
#             <div id="ee26291d-5107-41da-af77-c72e62c3f3da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ee26291d-5107-41da-af77-c72e62c3f3da")) {
#                     Plotly.newPlot(
#                         'ee26291d-5107-41da-af77-c72e62c3f3da',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Uttar Pradesh", "marker": {"color": "#F8766D"}, "name": "Uttar Pradesh", "offsetgroup": "Uttar Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Uttar Pradesh"], "xaxis": "x", "y": [174], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Maharashtra", "marker": {"color": "#A3A500"}, "name": "Maharashtra", "offsetgroup": "Maharashtra", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Maharashtra"], "xaxis": "x", "y": [70], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#00BF7D"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [55], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Kerala", "marker": {"color": "#00B0F6"}, "name": "Kerala", "offsetgroup": "Kerala", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Kerala"], "xaxis": "x", "y": [53], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Madhya Pradesh", "marker": {"color": "#E76BF3"}, "name": "Madhya Pradesh", "offsetgroup": "Madhya Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh"], "xaxis": "x", "y": [51], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Delhi", "marker": {"color": "#F8766D"}, "name": "Delhi", "offsetgroup": "Delhi", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Delhi"], "xaxis": "x", "y": [47], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Bihar", "marker": {"color": "#A3A500"}, "name": "Bihar", "offsetgroup": "Bihar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bihar"], "xaxis": "x", "y": [43], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#00BF7D"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [42], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Gujarat", "marker": {"color": "#00B0F6"}, "name": "Gujarat", "offsetgroup": "Gujarat", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Gujarat"], "xaxis": "x", "y": [37], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Odisha", "marker": {"color": "#E76BF3"}, "name": "Odisha", "offsetgroup": "Odisha", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Odisha"], "xaxis": "x", "y": [35], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>District=%{y}", "legendgroup": "Assam", "marker": {"color": "#F8766D"}, "name": "Assam", "offsetgroup": "Assam", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Assam"], "xaxis": "x", "y": [33], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{ ...

# %%
fig = px.bar(hmis[['State', 'SubDistrict']].sort_values('SubDistrict', ascending=False), 
             y="SubDistrict", x="State", color='State', 
             log_y=True, template='ggplot2', title='SubDistrict Hospitals')
fig.show()
# Out:
# <div>
#
#
#             <div id="edbb9b9e-b782-4c7c-9c0a-21a504db2fae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("edbb9b9e-b782-4c7c-9c0a-21a504db2fae")) {
#                     Plotly.newPlot(
#                         'edbb9b9e-b782-4c7c-9c0a-21a504db2fae',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Tamil Nadu", "marker": {"color": "#F8766D"}, "name": "Tamil Nadu", "offsetgroup": "Tamil Nadu", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tamil Nadu"], "xaxis": "x", "y": [310.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#A3A500"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [147.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Maharashtra", "marker": {"color": "#00BF7D"}, "name": "Maharashtra", "offsetgroup": "Maharashtra", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Maharashtra"], "xaxis": "x", "y": [101.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Kerala", "marker": {"color": "#00B0F6"}, "name": "Kerala", "offsetgroup": "Kerala", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Kerala"], "xaxis": "x", "y": [82.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Madhya Pradesh", "marker": {"color": "#E76BF3"}, "name": "Madhya Pradesh", "offsetgroup": "Madhya Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh"], "xaxis": "x", "y": [72.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#F8766D"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [70.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Rajasthan", "marker": {"color": "#A3A500"}, "name": "Rajasthan", "offsetgroup": "Rajasthan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Rajasthan"], "xaxis": "x", "y": [64.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Himachal Pradesh", "marker": {"color": "#00BF7D"}, "name": "Himachal Pradesh", "offsetgroup": "Himachal Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Himachal Pradesh"], "xaxis": "x", "y": [61.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Telangana", "marker": {"color": "#00B0F6"}, "name": "Telangana", "offsetgroup": "Telangana", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Telangana"], "xaxis": "x", "y": [47.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Punjab", "marker": {"color": "#E76BF3"}, "name": "Punjab", "offsetgroup": "Punjab", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Punjab"], "xaxis": "x", "y": [47.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>SubDistrict=%{y}", "legendgroup": "Gujarat", "marker": {"color": "#F8766D"}, "name": "Gujarat", "offsetgroup": "Gujarat", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Gujarat"], "xaxis" ...

# %%
nhp = nhp.fillna(0)
nhp['Total_hospitals'] = nhp['Rural_hospitals'] + nhp['Urban_hospitals']
nhp['Total_beds'] = nhp['Rural_beds'] + nhp['Urban_beds']

# %%
nhp.head()
# Out:
#    Sno                      State  Latitude  Longitude  Rural_hospitals  \
# 0    1  Andaman & Nicobar Islands   11.6234    92.7265               27
# 1    2             Andhra Pradesh   15.9129    79.7400              193
# 2    3          Arunachal Pradesh   27.0844    93.6053              208
# 3    4                      Assam   26.1433    91.7898             1176
# 4    5                      Bihar   25.5941    85.1376              930
#
#    Rural_beds  Urban_hospitals  Urban_beds  Total_hospitals  Total_beds
# 0         575                3         500               30        1075
# 1        6480               65       16658              258       23138
# 2        2136               10         268              218        2404
# 3       10944               50        6198             1226       17142
# 4        6083              103        5936             1033       12019

# %% [markdown]
# # Total Beds

# %%
ms = nhp.sort_values(by=['Total_beds'],ascending=False)
ms = ms.head(30)
fig = px.funnel(ms, x='Total_beds', y='State')
fig.show()
# Out:
# <div>
#
#
#             <div id="f9b0e409-2b20-4568-b720-95628e4bc568" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f9b0e409-2b20-4568-b720-95628e4bc568")) {
#                     Plotly.newPlot(
#                         'f9b0e409-2b20-4568-b720-95628e4bc568',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Total_beds=%{x}<br>State=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "orientation": "h", "showlegend": false, "type": "funnel", "x": [78566, 77532, 76260, 70165, 51446, 38004, 32280, 31848, 28839, 24383, 23138, 20983, 18519, 17933, 17142, 12399, 12019, 11651, 11240, 10784, 9412, 8512, 4457, 4417, 3569, 3013, 2404, 1997, 1880, 1560], "xaxis": "x", "y": ["West Bengal", "Tamil Nadu", "Uttar Pradesh", "Karnataka", "Maharashtra", "Kerala", "Gujarat", "Rajasthan", "Madhya Pradesh", "Delhi", "Andhra Pradesh", "Telangana", "Odisha", "Punjab", "Assam", "Himachal Pradesh", "Bihar", "Jammu & Kashmir", "Haryana", "Jharkhand", "Chhattisgarh", "Uttarakhand", "Meghalaya", "Tripura", "Puducherry", "Goa", "Arunachal Pradesh", "Mizoram", "Nagaland", "Sikkim"], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
fig = px.bar(nhp[['State', 'Total_hospitals']].sort_values('Total_hospitals', ascending=False), 
             y="Total_hospitals", x="State", color='State', 
             log_y=True, template='ggplot2', title='Total Hospitals')
fig.show()
# Out:
# <div>
#
#
#             <div id="c105057a-b572-4baf-b140-05b1ee1aef93" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c105057a-b572-4baf-b140-05b1ee1aef93")) {
#                     Plotly.newPlot(
#                         'c105057a-b572-4baf-b140-05b1ee1aef93',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Uttar Pradesh", "marker": {"color": "#F8766D"}, "name": "Uttar Pradesh", "offsetgroup": "Uttar Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Uttar Pradesh"], "xaxis": "x", "y": [4635], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#A3A500"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [2845], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Odisha", "marker": {"color": "#00BF7D"}, "name": "Odisha", "offsetgroup": "Odisha", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Odisha"], "xaxis": "x", "y": [1804], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#00B0F6"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [1566], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Kerala", "marker": {"color": "#E76BF3"}, "name": "Kerala", "offsetgroup": "Kerala", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Kerala"], "xaxis": "x", "y": [1280], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Assam", "marker": {"color": "#F8766D"}, "name": "Assam", "offsetgroup": "Assam", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Assam"], "xaxis": "x", "y": [1226], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Tamil Nadu", "marker": {"color": "#A3A500"}, "name": "Tamil Nadu", "offsetgroup": "Tamil Nadu", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tamil Nadu"], "xaxis": "x", "y": [1217], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Bihar", "marker": {"color": "#00BF7D"}, "name": "Bihar", "offsetgroup": "Bihar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bihar"], "xaxis": "x", "y": [1033], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Telangana", "marker": {"color": "#00B0F6"}, "name": "Telangana", "offsetgroup": "Telangana", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Telangana"], "xaxis": "x", "y": [863], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Himachal Pradesh", "marker": {"color": "#E76BF3"}, "name": "Himachal Pradesh", "offsetgroup": "Himachal Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Himachal Pradesh"], "xaxis": "x", "y": [801], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Total_hospitals=%{y}", "legendgroup": "Rajasthan", "marker": {"color": "#F8766D"}, "name": "Rajasthan", "offsetgroup": "Rajasthan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Rajasthan"], "xax ...

# %%
fig = px.bar(nhp[['State', 'Rural_hospitals']].sort_values('Rural_hospitals', ascending=False), 
             y="Rural_hospitals", x="State", color='State', 
             log_y=True, template='ggplot2', title='Rural Hospitals')
fig.show()
# Out:
# <div>
#
#
#             <div id="c3cf2cee-e02e-4610-b474-d19e037f6b21" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c3cf2cee-e02e-4610-b474-d19e037f6b21")) {
#                     Plotly.newPlot(
#                         'c3cf2cee-e02e-4610-b474-d19e037f6b21',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Uttar Pradesh", "marker": {"color": "#F8766D"}, "name": "Uttar Pradesh", "offsetgroup": "Uttar Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Uttar Pradesh"], "xaxis": "x", "y": [4442], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#A3A500"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [2471], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Odisha", "marker": {"color": "#00BF7D"}, "name": "Odisha", "offsetgroup": "Odisha", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Odisha"], "xaxis": "x", "y": [1655], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#00B0F6"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [1272], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Assam", "marker": {"color": "#E76BF3"}, "name": "Assam", "offsetgroup": "Assam", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Assam"], "xaxis": "x", "y": [1176], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Kerala", "marker": {"color": "#F8766D"}, "name": "Kerala", "offsetgroup": "Kerala", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Kerala"], "xaxis": "x", "y": [981], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Bihar", "marker": {"color": "#A3A500"}, "name": "Bihar", "offsetgroup": "Bihar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bihar"], "xaxis": "x", "y": [930], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Telangana", "marker": {"color": "#00BF7D"}, "name": "Telangana", "offsetgroup": "Telangana", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Telangana"], "xaxis": "x", "y": [802], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Himachal Pradesh", "marker": {"color": "#00B0F6"}, "name": "Himachal Pradesh", "offsetgroup": "Himachal Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Himachal Pradesh"], "xaxis": "x", "y": [705], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Tamil Nadu", "marker": {"color": "#E76BF3"}, "name": "Tamil Nadu", "offsetgroup": "Tamil Nadu", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tamil Nadu"], "xaxis": "x", "y": [692], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_hospitals=%{y}", "legendgroup": "Haryana", "marker": {"color": "#F8766D"}, "name": "Haryana", "offsetgroup": "Haryana", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Haryana"], "xaxis": "x", " ...

# %%
fig = px.bar(nhp[['State', 'Rural_beds']].sort_values('Rural_beds', ascending=False), 
             y="Rural_beds", x="State", color='State', 
             log_y=True, template='ggplot2', title='Rural Beds')
fig.show()
# Out:
# <div>
#
#
#             <div id="81afdbdd-534b-43de-8c75-0f741e756f8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("81afdbdd-534b-43de-8c75-0f741e756f8e")) {
#                     Plotly.newPlot(
#                         '81afdbdd-534b-43de-8c75-0f741e756f8e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Tamil Nadu", "marker": {"color": "#F8766D"}, "name": "Tamil Nadu", "offsetgroup": "Tamil Nadu", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tamil Nadu"], "xaxis": "x", "y": [40179], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Uttar Pradesh", "marker": {"color": "#A3A500"}, "name": "Uttar Pradesh", "offsetgroup": "Uttar Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Uttar Pradesh"], "xaxis": "x", "y": [39104], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Rajasthan", "marker": {"color": "#00BF7D"}, "name": "Rajasthan", "offsetgroup": "Rajasthan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Rajasthan"], "xaxis": "x", "y": [21088], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#00B0F6"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [21072], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#E76BF3"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [19684], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Kerala", "marker": {"color": "#F8766D"}, "name": "Kerala", "offsetgroup": "Kerala", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Kerala"], "xaxis": "x", "y": [16865], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Maharashtra", "marker": {"color": "#A3A500"}, "name": "Maharashtra", "offsetgroup": "Maharashtra", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Maharashtra"], "xaxis": "x", "y": [12398], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Gujarat", "marker": {"color": "#00BF7D"}, "name": "Gujarat", "offsetgroup": "Gujarat", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Gujarat"], "xaxis": "x", "y": [11715], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Assam", "marker": {"color": "#00B0F6"}, "name": "Assam", "offsetgroup": "Assam", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Assam"], "xaxis": "x", "y": [10944], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Madhya Pradesh", "marker": {"color": "#E76BF3"}, "name": "Madhya Pradesh", "offsetgroup": "Madhya Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh"], "xaxis": "x", "y": [10020], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Rural_beds=%{y}", "legendgroup": "Telangana", "marker": {"color": "#F8766D"}, "name": "Telangana", "offsetgroup": "Telangana", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Telangana"], "xaxis": "x", "y": [7668],  ...

# %%
fig = px.bar(nhp[['State', 'Urban_hospitals']].sort_values('Urban_hospitals', ascending=False), 
             y="Urban_hospitals", x="State", color='State', 
             log_y=True, template='ggplot2', title='Urban Hospitals')
fig.show()
# Out:
# <div>
#
#
#             <div id="804bf0aa-376f-47d8-810a-aaa27456fc1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("804bf0aa-376f-47d8-810a-aaa27456fc1c")) {
#                     Plotly.newPlot(
#                         '804bf0aa-376f-47d8-810a-aaa27456fc1c',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Tamil Nadu", "marker": {"color": "#F8766D"}, "name": "Tamil Nadu", "offsetgroup": "Tamil Nadu", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tamil Nadu"], "xaxis": "x", "y": [525], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Maharashtra", "marker": {"color": "#A3A500"}, "name": "Maharashtra", "offsetgroup": "Maharashtra", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Maharashtra"], "xaxis": "x", "y": [438], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#00BF7D"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [374], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Kerala", "marker": {"color": "#00B0F6"}, "name": "Kerala", "offsetgroup": "Kerala", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Kerala"], "xaxis": "x", "y": [299], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#E76BF3"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [294], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Uttar Pradesh", "marker": {"color": "#F8766D"}, "name": "Uttar Pradesh", "offsetgroup": "Uttar Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Uttar Pradesh"], "xaxis": "x", "y": [193], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Punjab", "marker": {"color": "#A3A500"}, "name": "Punjab", "offsetgroup": "Punjab", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Punjab"], "xaxis": "x", "y": [172], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Rajasthan", "marker": {"color": "#00BF7D"}, "name": "Rajasthan", "offsetgroup": "Rajasthan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Rajasthan"], "xaxis": "x", "y": [150], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Odisha", "marker": {"color": "#00B0F6"}, "name": "Odisha", "offsetgroup": "Odisha", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Odisha"], "xaxis": "x", "y": [149], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Gujarat", "marker": {"color": "#E76BF3"}, "name": "Gujarat", "offsetgroup": "Gujarat", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Gujarat"], "xaxis": "x", "y": [122], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_hospitals=%{y}", "legendgroup": "Madhya Pradesh", "marker": {"color": "#F8766D"}, "name": "Madhya Pradesh", "offsetgroup": "Madhya Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh"],  ...

# %%
fig = px.bar(nhp[['State', 'Urban_beds']].sort_values('Urban_beds', ascending=False), 
             y="Urban_beds", x="State", color='State', 
             log_y=True, template='ggplot2', title='Urban beds')
fig.show()
# Out:
# <div>
#
#
#             <div id="bfd7eb54-99d9-44c2-b8f0-00ecef94ef04" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bfd7eb54-99d9-44c2-b8f0-00ecef94ef04")) {
#                     Plotly.newPlot(
#                         'bfd7eb54-99d9-44c2-b8f0-00ecef94ef04',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "West Bengal", "marker": {"color": "#F8766D"}, "name": "West Bengal", "offsetgroup": "West Bengal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["West Bengal"], "xaxis": "x", "y": [58882], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Karnataka", "marker": {"color": "#A3A500"}, "name": "Karnataka", "offsetgroup": "Karnataka", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Karnataka"], "xaxis": "x", "y": [49093], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Maharashtra", "marker": {"color": "#00BF7D"}, "name": "Maharashtra", "offsetgroup": "Maharashtra", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Maharashtra"], "xaxis": "x", "y": [39048], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Tamil Nadu", "marker": {"color": "#00B0F6"}, "name": "Tamil Nadu", "offsetgroup": "Tamil Nadu", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Tamil Nadu"], "xaxis": "x", "y": [37353], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Uttar Pradesh", "marker": {"color": "#E76BF3"}, "name": "Uttar Pradesh", "offsetgroup": "Uttar Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Uttar Pradesh"], "xaxis": "x", "y": [37156], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Delhi", "marker": {"color": "#F8766D"}, "name": "Delhi", "offsetgroup": "Delhi", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Delhi"], "xaxis": "x", "y": [24383], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Kerala", "marker": {"color": "#A3A500"}, "name": "Kerala", "offsetgroup": "Kerala", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Kerala"], "xaxis": "x", "y": [21139], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Gujarat", "marker": {"color": "#00BF7D"}, "name": "Gujarat", "offsetgroup": "Gujarat", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Gujarat"], "xaxis": "x", "y": [20565], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Madhya Pradesh", "marker": {"color": "#00B0F6"}, "name": "Madhya Pradesh", "offsetgroup": "Madhya Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Madhya Pradesh"], "xaxis": "x", "y": [18819], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Andhra Pradesh", "marker": {"color": "#E76BF3"}, "name": "Andhra Pradesh", "offsetgroup": "Andhra Pradesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Andhra Pradesh"], "xaxis": "x", "y": [16658], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "State=%{x}<br>Urban_beds=%{y}", "legendgroup": "Telangana", "marker": {"color": "#F8766D"}, "name": "Telangana", "offsetgroup": "Telangana", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Telangana"], "xaxis" ...
